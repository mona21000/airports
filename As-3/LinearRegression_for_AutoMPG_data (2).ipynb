# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#plt.style.use('seaborn-whitegrid')

# %%
df = pd.read_excel('autoMPG_data.xlsx')

# %%
df.head()
# Out:
#    GallonsPer100Miles  GallonsPer100MilesTo1981   MPG  Cylinders  \
# 0            5.555556                  5.555556  18.0          8
# 1            6.666667                  6.666667  15.0          8
# 2            5.555556                  5.555556  18.0          8
# 3            6.250000                  6.250000  16.0          8
# 4            5.882353                  5.882353  17.0          8
#
#    Displacement100ci  Horsepower100  Weight1000lb  Seconds0to60  Year  \
# 0               3.07           1.30         3.504          12.0    70
# 1               3.50           1.65         3.693          11.5    70
# 2               3.18           1.50         3.436          11.0    70
# 3               3.04           1.50         3.433          12.0    70
# 4               3.02           1.40         3.449          10.5    70
#
#    Year70To81  Origin  Origin.Eq.1  Origin.Eq.2  Origin.Eq.3  \
# 0           1       1            1            0            0
# 1           1       1            1            0            0
# 2           1       1            1            0            0
# 3           1       1            1            0            0
# 4           1       1            1            0            0
#
#                         Name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
df['Weight1000lb'].min()
# Out:
# 1.613

# %%
df['Weight1000lb'].max()
# Out:
# 5.14

# %%
df['Weight1000lb'].hist()
# Out:
# <AxesSubplot:>

# %%
df['MPG'].hist()
# Out:
# <AxesSubplot:>

# %%
# let's see the scatter plots and have the regression line fitted also for illustrations
sns.pairplot(df, kind = 'reg')

# %%
df.corr()
# Out:
#                           GallonsPer100Miles  GallonsPer100MilesTo1981  \
# GallonsPer100Miles                  1.000000                  1.000000
# GallonsPer100MilesTo1981            1.000000                  1.000000
# MPG                                -0.935935                 -0.934841
# Cylinders                           0.839385                  0.835720
# Displacement100ci                   0.866050                  0.866894
# Horsepower100                       0.854809                  0.853023
# Weight1000lb                        0.885056                  0.884828
# Seconds0to60                       -0.456338                 -0.461391
# Year                               -0.558255                 -0.508736
# Year70To81                          0.272419                       NaN
# Origin                             -0.532932                 -0.560899
# Origin.Eq.1                         0.546366                  0.579838
# Origin.Eq.2                        -0.264829                 -0.299749
# Origin.Eq.3                        -0.409405                 -0.417987
#
#                                MPG  Cylinders  Displacement100ci  \
# GallonsPer100Miles       -0.935935   0.839385           0.866050
# GallonsPer100MilesTo1981 -0.934841   0.835720           0.866894
# MPG                       1.000000  -0.777618          -0.805127
# Cylinders                -0.777618   1.000000           0.950823
# Displacement100ci        -0.805127   0.950823           1.000000
# Horsepower100            -0.778427   0.842983           0.897257
# Weight1000lb             -0.832244   0.897527           0.932994
# Seconds0to60              0.423329  -0.504683          -0.543800
# Year                      0.580541  -0.345647          -0.369855
# Year70To81               -0.315908   0.214933           0.182566
# Origin                    0.565209  -0.568932          -0.614535
# Origin.Eq.1              -0.565161   0.610494           0.655936
# Origin.Eq.2               0.244313  -0.352324          -0.371633
# Origin.Eq.3               0.451454  -0.404209          -0.440825
#
#                           Horsepower100  Weight1000lb  Seconds0to60      Year  \
# GallonsPer100Miles             0.854809      0.885056     -0.456338 -0.558255
# GallonsPer100MilesTo1981       0.853023      0.884828     -0.461391 -0.508736
# MPG                           -0.778427     -0.832244      0.423329  0.580541
# Cylinders                      0.842983      0.897527     -0.504683 -0.345647
# Displacement100ci              0.897257      0.932994     -0.543800 -0.369855
# Horsepower100                  1.000000      0.864538     -0.689196 -0.416361
# Weight1000lb                   0.864538      1.000000     -0.416839 -0.309120
# Seconds0to60                  -0.689196     -0.416839      1.000000  0.290316
# Year                          -0.416361     -0.309120      0.290316  1.000000
# Year70To81                     0.172258      0.184409     -0.101206 -0.471084
# Origin                        -0.455171     -0.585005      0.212746  0.181528
# Origin.Eq.1                    0.489625      0.600978     -0.258224 -0.136065
# Origin.Eq.2                   -0.284948     -0.293841      0.208298 -0.037745
# Origin.Eq.3                   -0.321936     -0.447929      0.115020  0.199841
#
#                           Year70To81    Origin  Origin.Eq.1  Origin.Eq.2  \
# GallonsPer100Miles          0.272419 -0.532932     0.546366    -0.264829
# GallonsPer100MilesTo1981         NaN -0.560899     0.579838    -0.299749
# MPG                        -0.315908  0.565209    -0.565161     0.244313
# Cylinders                   0.214933 -0.568932     0.610494    -0.352324
# Displacement100ci           0.182566 -0.614535     0.655936    -0.371633
# Horsepower100               0.172258 -0.455171     0.489625    -0.284948
# Weight1000lb                0.184409 -0.585005     0.600978    -0.293841
# Seconds0to60               -0.101206  0.212746    -0.258224     0.208298
# Year                       -0.471084  0.181528    -0.136065    -0.037745
# Year70To81                  1.000000 -0.032254    -0.004955     0.081198
# Origin                     -0.032254  1.000000    -0.925180     0.241148
# Origin.Eq.1                -0.004955 -0.925180     1.000000    -0.591434
# Origin.Eq.2                 0.081198  0.241148    -0.591434     1.000000
# Origin.Eq.3                -0.070666  0.888933    -0.648583    -0.230157
#
#                           Origin.Eq.3
# GallonsPer100Miles          -0.409405
# GallonsPer100MilesTo1981    -0.417987
# MPG                          0.451454
# Cylinders                   -0.404209
# Displacement100ci           -0.440825
# Horsepower100               -0.321936
# Weight1000lb                -0.447929
# Seconds0to60                 0.115020
# Year                         0.199841
# Year70To81                  -0.070666
# Origin                       0.888933
# Origin.Eq.1                 -0.648583
# Origin.Eq.2                 -0.230157
# Origin.Eq.3                  1.000000

# %%
# heatmap korrelaatiokertoimista
#sns.heatmap(df.corr(), annot = True)
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Let's check MPG and Weight1000lb as a jointplot
ax1 = sns.jointplot(data = df, x = 'MPG', y = 'Weight1000lb')
#ax1 = sns.jointplot(data = df, x = 'MPG', y = 'Horsepower100')

# %%
# On the other hand, let's see what happens if we use X='GallonsPer100Miles' instead
ax1 = sns.jointplot(data = df, x = 'GallonsPer100Miles', y = 'Weight1000lb')
#ax1 = sns.jointplot(data = df, x = 'GallonsPer100Miles', y = 'Horsepower100')
#ax1 = sns.jointplot(data = df, x = 'Weight1000lb', y = 'GallonsPer100Miles', kind='reg')

# %%
# Let's prepare the data for the regression model
X = df['Weight1000lb'].to_frame()  # to_frame() makes it dataframe as now it would only be a Series!

# This is the independent variable -> you could have taken more variables into your model as there can be more than one dependent variables

# %%
y = df['GallonsPer100Miles']  # This is your dependent variable - or the target variable that you want to predict

# %%
# Now that we have the data, let's start training the model

# %%
from sklearn.linear_model import LinearRegression

fuel_model = LinearRegression().fit(X,y)

# %%
fuel_model.coef_

# %%
fuel_model.intercept_

# %%
# Let's just predict first that how many GallonsPer100Miles would it take based on the model if the car would weight 1000lb
fuel_model.predict(pd.DataFrame([3]))   # This value is on the interpolation range

# %%
fuel_model.predict(pd.DataFrame([1]))   # This value is on the extrapolation range

# %%
#Let's plot the model error terms as a scatterplot
# X = Weight1000lb
# y = GallonsPer100Miles
plt.scatter(fuel_model.predict(X), fuel_model.predict(X)-y)

plt.hlines(y=0,xmin=2,xmax=9)

# %%
#Coefficient of determination
fuel_model.score(X,y)

# %%
# Hence, the model explains 78.3% of fuel consumtion
